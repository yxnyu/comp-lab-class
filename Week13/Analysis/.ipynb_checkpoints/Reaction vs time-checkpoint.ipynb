# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data3=pd.read_csv('MONITOR-1.ener',header=0,names=['#Step','Time[fs]','Kin.[a.u.]','Temp[K]','Pot.[a.u.]','Cons Qty[a.u.]','UsedTime[s]','[2]','[3]','[4]'],sep='\s+')
data4=pd.read_csv('MONITOR-COLVAR.metadynLog',header=0,names=['time','reaction','[2]','[3]','[4]','[5]'],sep='\s+')

# %%
data5=pd.read_csv('METADYN-COLVAR.metadynLog',header=0,names=['time','reaction','[2]','[3]','[4]','[5]'],sep='\s+')


data6=pd.read_csv('METADYN2-COLVAR.metadynLog',header=0,names=['time','reaction','[2]','[3]','[4]','[5]'],sep='\s+')
data7=pd.read_csv('METADYNfreq-COLVAR.metadynLog',header=0,names=['time','reaction','[2]','[3]','[4]','[5]'],sep='\s+')

# %%
plt.plot(data4['time'][189:],data4['reaction'][189:])
plt.xlabel('Time[fs]')
plt.ylabel('C-O distance[A]')
plt.title('Reaction vs Time,monitor')
plt.show()
plt.show()

# %%
plt.plot(data5['time'],data5['reaction'])
plt.plot(data4['time'][189:],data4['reaction'][189:])

#NT_HILLS 100
#WIDTH 0.5 scales
#WW [kcalmol] 1.5
plt.annotate('NT_HILLS 100', xy=(0, 0), xytext=(0, -20), xycoords='axes fraction', textcoords='offset points', va='top')
plt.annotate('WIDTH 0.5 scales', xy=(0, 0), xytext=(0, -40), xycoords='axes fraction', textcoords='offset points', va='top')
plt.annotate('WW [kcalmol] 1.5', xy=(0, 0), xytext=(0, -60), xycoords='axes fraction', textcoords='offset points', va='top')

# 显示图表
plt.xlabel('Time[fs]')
plt.ylabel('C-O distance[A]')
plt.title('Reaction vs Time,monitor and metad1_initmonitor')
plt.show()
plt.show()

# %%
plt.plot(data7['time'],data7['reaction'])


plt.annotate('NT_HILLS 20', xy=(0, 0), xytext=(0, -20), xycoords='axes fraction', textcoords='offset points', va='top')
plt.annotate('WIDTH 0.5 scales', xy=(0, 0), xytext=(0, -40), xycoords='axes fraction', textcoords='offset points', va='top')
plt.annotate('WW [kcalmol] 1.5', xy=(0, 0), xytext=(0, -60), xycoords='axes fraction', textcoords='offset points', va='top')

# 显示图表
plt.xlabel('Time[fs]')
plt.ylabel('C-O distance[A]')
plt.title('Reaction vs Time,metad1_initmonitor_freqhills')
plt.show()
plt.show()

# %%
plt.plot(data5['time'],data6['reaction'])
plt.plot(data7['time'],data7['reaction'])
plt.xlabel('Time[fs]')
plt.ylabel('C-O distance[A]')
plt.title('Reaction vs Time,metad1_initmonitor_freqhills and metad1_initmonitor')
plt.show()
plt.show()
