# %%
im

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data3=pd.read_csv('MONITOR-1.ener',header=0,names=['#Step','Time[fs]','Kin.[a.u.]','Temp[K]','Pot.[a.u.]','Cons Qty[a.u.]','UsedTime[s]','[2]','[3]','[4]'],sep='\s+')
data2=pd.read_csv('NPT-1.ener',header=0,names=['#Step','Time[fs]','Kin.[a.u.]','Temp[K]','Pot.[a.u.]','Cons Qty[a.u.]','UsedTime[s]','[2]','[3]','[4]'],sep='\s+')
data1=pd.read_csv('NVT-1.ener',header=0,names=['#Step','Time[fs]','Kin.[a.u.]','Temp[K]','Pot.[a.u.]','Cons Qty[a.u.]','UsedTime[s]','[2]','[3]','[4]'],sep='\s+')

# %%
plt.plot(data1['Time[fs]'],data1['Pot.[a.u.]'])

# %%
plt.plot(data2['Time[fs]'],data2['Pot.[a.u.]'])

# %%
plt.plot(data3['Time[fs]'],data3['Pot.[a.u.]'])
