# %%
import numpy as np
import matplotlib.pyplot as plt
import mdtraj as md

# %% [markdown]
# ## Masterclass Exercise 1 - Unbiased MD

# %%
#load data
time, phi, psi = np.loadtxt('dialaA_unbiased_phi-psi.colvar', unpack=True)
traj = md.load_xtc('dialaA_unbiasedMD_N10000000.xtc', top='dialaA.pdb')

phi_angles = md.compute_phi(traj) 
psi_angles = md.compute_psi(traj)

plt.scatter(phi, psi, label = 'plumed') #from plumed

plt.scatter(phi_angles[1], psi_angles[1], label = 'mdtraj') #from mdtraj

plt.xlabel('Phi Angle (rad)')
plt.ylabel('Psi Angle (rad)')
plt.legend()
plt.savefig('dialaA_unbiased_ramachandran')

plt.show()

# %% [markdown]
# complete overlap for plumed colvar data and angles computed via mdtraj!

# %%
# to obtain sigma values - between 1/3 and 1/2 of st dev of what we are biasing 

np.std(phi) * 5/12
# Out:
# 0.23076314343591697

# %%
np.std(psi) * 5/12
# Out:
# 0.4270408832259429

# %% [markdown]
# ## Lugano Exercise 1 - Biased MD

# %%
phi, energy, unknown = np.loadtxt('dialaA_metad_bias10_sigma0.23076.grid.dat', unpack=True)
plt.plot(phi, -energy)

plt.xlabel('Phi Angle (rad)')
plt.ylabel('Free Energy (kJ/mol)')

plt.savefig('dialaA_metad_fes_ex1')

plt.show()

# %% [markdown]
# ## Lugano Exercise 2  - Free Energy Surfaces

# %%
phi, energy, unknown = np.loadtxt('dialaA_metad_bias10_sigma0.23076.fes', unpack=True)

plt.plot(phi, energy)

plt.xlabel('Phi Angle (rad)')
plt.ylabel('Free Energy (kJ/mol)')

plt.savefig('dialaA_metad_fes_ex2')

plt.show()

# %% [markdown]
# looks the same as for exercise 1 but shifted down by 10 kJ/mol

# %%
## GIF to assess convergence

import glob
from PIL import Image

wd = '/scratch/work/courses/CHEM-GA-2671-2022fa/ns3539/comp-lab-class/Week6/TopologyA'

# %%
frames = []

for i in range(100):
    filename = f'dialaA_metad_bias10_sigma0.23076.100fes{i}.dat'
    phi, energy, unknown = np.loadtxt(filename, unpack=True)

    plt.plot(phi, energy)

    plt.xlabel('Phi Angle (rad)')
    plt.ylabel('Free Energy (kJ/mol)')

    savename = f'dialaA_metad_fes100_ex2_frame{i}'
    plt.savefig(savename)
    
    frame = [Image.open(image) for image in glob.glob(f"{savename}.png")]
    frames.append(frame[0])
    
frame_one = frames[0]
frame_one.save(f'{wd}/dialaA_metad_fes100_ex2.gif', format="GIF", append_images=frames,
           save_all=True, duration=100, loop=0)

plt.savefig('dialaA_metad_fes100_ex2')
plt.show()

# %% [markdown]
# ## 2D Metadynamics

# %%
# plot an arbitrary surface for visualization purposes 

i=34
filename = f'dialaA_2Dmetad_N5000000_bias10_sigma0.23076-0.427.fes{i}.dat'


phi, psi, energy, unknown1, unknown2 = np.loadtxt(filename, unpack=True)

plt.scatter(phi, energy)
plt.xlabel('Phi Angle (rad)')
plt.ylabel('Free Energy (kJ/mol)')
plt.show()

plt.scatter(psi, energy)
plt.xlabel('Psi Angle (rad)')
plt.ylabel('Free Energy (kJ/mol)')
plt.show()

# %%
# make gif 

frames = []

for i in range(101):
    if i%10==0:
        filename = f'dialaA_2Dmetad_N5000000_bias10_sigma0.23076-0.427.100fes{i}.dat'
        phi, psi, energy, unknown1, unknown2 = np.loadtxt(filename, unpack=True)

        plt.scatter(phi, energy)
        plt.xlabel('Phi Angle (rad)')
        plt.ylabel('Free Energy (kJ/mol)')

        savename = f'dialaB_2Dmetad_fes100_frame{i}'
        plt.savefig(savename)

        frame = [Image.open(image) for image in glob.glob(f"{savename}.png")]
        frames.append(frame[0])
    
frame_one = frames[0]
frame_one.save(f'{wd}/dialaA_2Dmetad_fes100.gif', format="GIF", append_images=frames,
           save_all=True, duration=100, loop=0)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-31ff3cfede65> in <module>
#       3 for i in range(100):
#       4     filename = f'dialaB_2Dmetad_N5000000_bias10_sigma0.055-0.14.100fes{i}.dat'
# ----> 5     phi, energy, unknown = np.loadtxt(filename, unpack=True)
#       6
#       7     plt.plot(phi, energy)
#
# ~/.local/lib/python3.8/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1311         delimiter = delimiter.decode('latin1')
#    1312
# -> 1313     arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1314                 converters=converters, skiplines=skiprows, usecols=usecols,
#    1315                 unpack=unpack, ndmin=ndmin, encoding=encoding,
#
# ~/.local/lib/python3.8/site-packages/numpy/lib/npyio.py in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     953             fname = os.fspath(fname)
#     954         if isinstance(fname, str):
# --> 955             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     956             if encoding is None:
#     957                 encoding = getattr(fh, 'encoding', 'latin1')
#
# ~/.local/lib/python3.8/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     191
#     192     ds = DataSource(destpath)
# --> 193     return ds.open(path, mode, encoding=encoding, newline=newline)
#     194
#     195
#
# ~/.local/lib/python3.8/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     531                                       encoding=encoding, newline=newline)
#     532         else:
# --> 533             raise FileNotFoundError(f"{path} not found.")
#     534
#     535
#
# FileNotFoundError: dialaB_2Dmetad_N5000000_bias10_sigma0.055-0.14.100fes0.dat not found.

# %%
dialaB_2Dmetad_N5000000_bias10_sigma0.055-0.14.100fes0.dat
