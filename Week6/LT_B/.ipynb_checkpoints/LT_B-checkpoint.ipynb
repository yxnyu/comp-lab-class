# %%
import numpy as np
import matplotlib.pyplot as plt
import mdtraj as md
import pandas as pd
import glob
from PIL import Image

# %%
#phi,none,energy, none1, none2=np.loadtxt('__FILENAME__.grid.dat',skiprows=9)

data=pd.read_csv('sigma_phi_energyA.grid.dat',header=0,names=['phi','energy','none2'],skiprows=5,sep='\s+')
# print pandas dataset
data
plt.plot(data.phi, -data.energy)
plt.xlabel('Phi Angle (rad)')
plt.ylabel('Free Energy (kJ/mol)')
plt.title('dialaA_metad_sigma(with sigma0.552)')
plt.savefig('dialaA_metad_sigma')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-84c395810adc> in <module>
#       1 #phi,none,energy, none1, none2=np.loadtxt('__FILENAME__.grid.dat',skiprows=9)
#       2
# ----> 3 data=pd.read_csv('sigma_phi_energyB.grid.dat',header=0,names=['phi','energy','none2'],skiprows=5,sep='\s+')
#       4 # print pandas dataset
#       5 data
#
# /share/apps/python/3.8.6/intel/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# /share/apps/python/3.8.6/intel/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# /share/apps/python/3.8.6/intel/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# /share/apps/python/3.8.6/intel/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# /share/apps/python/3.8.6/intel/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sigma_phi_energyB.grid.dat'

# %%
COL1d=np.loadtxt('COLVAR',skiprows=5)
time1d=np.zeros(100001,dtype=float)
phi1d=np.zeros(100001,dtype=float)
for i in range(100001):
    time1d[i]=COL1d[i][0]*0.001
    phi1d[i]=COL1d[i][1]
fig,ax=plt.subplots()
plt.scatter(time1d,phi1d)
ax.set_xlabel('Time (ns)')
ax.set_ylabel('Phi')
ax.set_title("Phi-Time ")
# Out:
# Text(0.5, 1.0, 'Phi-Time ')

# %%
hills=pd.read_csv('HILLS',header=0,names=['time','phi','sigma','height','none2'],skiprows=5,sep='\s+')
fig,ax=plt.subplots()
print(hills.height)
plt.scatter(hills.time,hills.height)
ax.set_xlabel("Time (ns)")
ax.set_ylabel('Gaussian Hill Height (kJ/mol)')
ax.set_title("Hill heights - time for dialaA")
# Out:
# 0       1.317579
# 1       1.239668
# 2       1.199437
# 3       1.162355
# 4       1.239966
#           ...
# 9994    0.046873
# 9995    0.012308
# 9996    0.021024
# 9997    0.007009
# 9998    0.006427
# Name: height, Length: 9999, dtype: float64
# Text(0.5, 1.0, 'Hill heights - time for dialaA')

# %%
phi1, energy1, unknown= np.loadtxt('fes.dat', unpack=True)

plt.plot(phi1, energy1)

plt.xlabel('Phi Angle (rad)')
plt.ylabel('Free Energy (kJ/mol)')
plt.title('dialaA_metad_fes(with sigma0.552)')
plt.savefig('dialaA_metad_fes')

plt.show()

# %% [markdown]
# After checking the document, The 1.1 scale is the constant we need to

# %%
phi, energy, unknown= np.loadtxt('fes.dat', unpack=True)
plt.plot(phi, energy/1.1)
plt.plot(phi1, energy1/1.1)
plt.xlabel('Phi Angle (rad)')
plt.ylabel('Free Energy (kJ/mol)')
plt.title('dialaA_fes and grid file cover with 1.1 (with sigma0.552)')
plt.savefig('dialaA_fes_cover_with_constant')
plt.show()

# %%
frames = []

for i in range(100):
    filename = f'fes_{i}.dat'
    phi, energy, unknown = np.loadtxt(filename, unpack=True)

    plt.plot(phi, energy)

    plt.xlabel('Phi Angle (rad)')
    plt.ylabel('Free Energy (kJ/mol)')
plt.title('dialaA_metad_sigma0.552_fes100')
plt.show()

# %%
grid=np.loadtxt('dialaA_meta2d_fes2d.dat',skiprows=9)
